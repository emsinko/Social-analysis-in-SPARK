# %% [markdown]
# # Create predictive model
# <br>
# ## Task
# Construct model that is going to predict if an influencer is going to publish a post next day or not. Model it as binary classification.
#
# ## Data
# * use two datasets about influencers
# * the first dataset contains basic information about each influencer
# * the second dataset contains posting history for each influncer for the past 6 months
#
# ## Notes
# * the posting history is for the period 1.1.2018 - 1.8.2018
# * assume it is 31.7.2017 and make a prediction for the next day
# * extract the labels for 1.8. to constract the training and test dataset
# * extract some features from the available data
# * experiment with these models: Logistic regression (lr), decision tree (dt), random forest (rf)
# * Try to construct some basic model first and than improve it by adding some more features

# %% [markdown]
# ## Documentation
# <br>
# * Pyspark documentation of DataFrame API is <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html">here</a>
#
# * Pyspark documentation of ML Pipelines library is <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html">here</a>
#
# * Prezentation slides are accessed <a target="_blank" href = "https://docs.google.com/presentation/d/1XNKIfE5Atj_Mzse0wjmbwLecmVs2YkWm9cqOLqDVWPo/edit?usp=sharing">here</a>

# %% [markdown]
# ### Import functions and modules

# %%
from pyspark.sql.functions import col, max, datediff, count, desc, array_contains, broadcast, explode, length, first, when, expr, regexp_replace, row_number, coalesce, lit, coalesce, size

from pyspark.sql import Window


from pyspark.ml.tuning import CrossValidator, CrossValidatorModel, ParamGridBuilder
from pyspark.ml.classification import RandomForestClassifier, RandomForestClassificationModel
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml import Pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Load Data

# %%
infl = spark.table('mlprague.influencers')

posts_history = spark.table('mlprague.infl_posting_history')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### You may want to do some exploratory analytics first
#
# hint:
# * see how many records you have
# * what is the schema of the dataset
# * see some records
# * use can use printSchema(), show(), count(), or proprietaray function display()

# %%
# your code here:
infl.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>389553
# </div>

# %%
posts_history.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>30783526
# </div>

# %%
infl.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- influencer_id: integer (nullable = true)
# -- languages: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- interests: array (nullable = true)
#     |-- element: string (containsNull = true)
#
# </div>

# %%
posts_history.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- influencer_id: integer (nullable = true)
# -- post_date: date (nullable = true)
#
# </div>

# %%
display(infl)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th></tr></thead><tbody><tr><td>85194</td><td>List(en)</td><td>List(Family and relationships, Entertainment)</td></tr><tr><td>67648</td><td>List(fr)</td><td>List(Shopping and fashion)</td></tr><tr><td>184917</td><td>List(en)</td><td>List(Hobbies and activities, Food and drink, Family and relationships)</td></tr><tr><td>370126</td><td>List(en)</td><td>List(Hobbies and activities)</td></tr><tr><td>246388</td><td>List(es)</td><td>List(Sports and outdoors, Fitness and wellness)</td></tr><tr><td>228457</td><td>List(en)</td><td>List(Entertainment, Hobbies and activities)</td></tr><tr><td>122770</td><td>List(id)</td><td>List(Business and industry, Hobbies and activities)</td></tr><tr><td>41916</td><td>List(ru)</td><td>List(Food and drink, Business and industry, Family and relationships)</td></tr><tr><td>269152</td><td>List(hi)</td><td>List(Family and relationships, Hobbies and activities)</td></tr><tr><td>204386</td><td>List(ru)</td><td>List(Hobbies and activities)</td></tr><tr><td>387970</td><td>List(ru)</td><td>List(Hobbies and activities, Family and relationships, Food and drink)</td></tr><tr><td>292350</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Shopping and fashion)</td></tr><tr><td>352654</td><td>List(pt)</td><td>List(Business and industry, Shopping and fashion)</td></tr><tr><td>30976</td><td>List(pt)</td><td>List(Hobbies and activities, Fitness and wellness)</td></tr><tr><td>222806</td><td>List(es)</td><td>List(Business and industry, Hobbies and activities)</td></tr><tr><td>19041</td><td>List(ru)</td><td>List(Business and industry)</td></tr><tr><td>244736</td><td>List(fr)</td><td>List(Food and drink, Family and relationships, Entertainment)</td></tr><tr><td>140650</td><td>List(en)</td><td>List(Shopping and fashion, Family and relationships, Hobbies and activities)</td></tr><tr><td>112894</td><td>List(en)</td><td>List(Family and relationships)</td></tr><tr><td>232161</td><td>List(ru)</td><td>List(Shopping and fashion)</td></tr><tr><td>281250</td><td>List(en)</td><td>List(Shopping and fashion, Hobbies and activities)</td></tr><tr><td>189961</td><td>List(en)</td><td>List(Entertainment)</td></tr><tr><td>352585</td><td>List(en)</td><td>List(Hobbies and activities, Family and relationships)</td></tr><tr><td>280940</td><td>List(es)</td><td>List(Family and relationships)</td></tr><tr><td>44004</td><td>List(de)</td><td>List(Shopping and fashion)</td></tr><tr><td>126166</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Shopping and fashion)</td></tr><tr><td>359528</td><td>List(en)</td><td>List(Shopping and fashion)</td></tr><tr><td>246026</td><td>List(en)</td><td>List(Shopping and fashion)</td></tr><tr><td>30092</td><td>List(tr)</td><td>List(Entertainment, Hobbies and activities, Food and drink)</td></tr><tr><td>108214</td><td>List(en, tr)</td><td>List(Hobbies and activities)</td></tr><tr><td>302158</td><td>List(ru)</td><td>List(Hobbies and activities, Shopping and fashion, Family and relationships)</td></tr><tr><td>168006</td><td>List(de)</td><td>List(Business and industry, Hobbies and activities, Fitness and wellness)</td></tr><tr><td>283054</td><td>List(en)</td><td>List(Fitness and wellness, Shopping and fashion)</td></tr><tr><td>154653</td><td>List(en)</td><td>List(Shopping and fashion)</td></tr><tr><td>137970</td><td>List(en)</td><td>List(Food and drink, Hobbies and activities)</td></tr><tr><td>40667</td><td>List(ru)</td><td>List(Hobbies and activities, Sports and outdoors, Fitness and wellness)</td></tr><tr><td>83938</td><td>List(en, es)</td><td>List(Entertainment)</td></tr><tr><td>282149</td><td>List(pt)</td><td>List(Family and relationships)</td></tr><tr><td>1163</td><td>List(pt)</td><td>List(Entertainment, Shopping and fashion, Family and relationships)</td></tr><tr><td>45063</td><td>List(pt)</td><td>Li ...

# %%
display(posts_history)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>post_date</th></tr></thead><tbody><tr><td>55769</td><td>2018-05-28</td></tr><tr><td>185791</td><td>2018-03-11</td></tr><tr><td>272845</td><td>2018-06-17</td></tr><tr><td>174005</td><td>2018-06-08</td></tr><tr><td>320590</td><td>2018-07-22</td></tr><tr><td>154641</td><td>2018-07-16</td></tr><tr><td>326720</td><td>2018-04-07</td></tr><tr><td>349143</td><td>2018-04-30</td></tr><tr><td>291156</td><td>2018-06-04</td></tr><tr><td>244638</td><td>2018-02-25</td></tr><tr><td>271638</td><td>2018-05-08</td></tr><tr><td>66435</td><td>2018-02-20</td></tr><tr><td>64912</td><td>2018-05-03</td></tr><tr><td>232152</td><td>2018-03-02</td></tr><tr><td>35716</td><td>2018-04-07</td></tr><tr><td>213550</td><td>2018-04-15</td></tr><tr><td>80934</td><td>2018-05-30</td></tr><tr><td>336964</td><td>2018-07-17</td></tr><tr><td>156455</td><td>2018-05-22</td></tr><tr><td>131859</td><td>2018-04-30</td></tr><tr><td>380482</td><td>2018-03-08</td></tr><tr><td>215865</td><td>2018-04-07</td></tr><tr><td>379024</td><td>2018-03-25</td></tr><tr><td>381014</td><td>2018-03-13</td></tr><tr><td>208053</td><td>2018-07-19</td></tr><tr><td>250782</td><td>2018-06-29</td></tr><tr><td>148442</td><td>2018-05-26</td></tr><tr><td>330791</td><td>2018-02-18</td></tr><tr><td>80065</td><td>2018-07-07</td></tr><tr><td>274087</td><td>2018-04-18</td></tr><tr><td>225654</td><td>2018-03-30</td></tr><tr><td>270680</td><td>2018-08-01</td></tr><tr><td>90091</td><td>2018-05-10</td></tr><tr><td>207280</td><td>2018-07-19</td></tr><tr><td>134665</td><td>2018-05-12</td></tr><tr><td>211764</td><td>2018-03-21</td></tr><tr><td>348181</td><td>2018-06-18</td></tr><tr><td>29277</td><td>2018-06-26</td></tr><tr><td>172683</td><td>2018-05-13</td></tr><tr><td>129524</td><td>2018-07-28</td></tr><tr><td>211150</td><td>2018-03-03</td></tr><tr><td>58101</td><td>2018-07-12</td></tr><tr><td>165476</td><td>2018-06-21</td></tr><tr><td>252705</td><td>2018-03-17</td></tr><tr><td>324245</td><td>2018-04-29</td></tr><tr><td>47672</td><td>2018-03-18</td></tr><tr><td>88101</td><td>2018-07-01</td></tr><tr><td>55257</td><td>2018-07-18</td></tr><tr><td>351194</td><td>2018-03-28</td></tr><tr><td>138187</td><td>2018-07-20</td></tr><tr><td>37177</td><td>2018-02-01</td></tr><tr><td>63376</td><td>2018-06-11</td></tr><tr><td>274914</td><td>2018-07-11</td></tr><tr><td>210010</td><td>2018-05-17</td></tr><tr><td>71158</td><td>2018-07-27</td></tr><tr><td>279189</td><td>2018-06-16</td></tr><tr><td>191630</td><td>2018-07-21</td></tr><tr><td>319725</td><td>2018-07-02</td></tr><tr><td>314007</td><td>2018-05-16</td></tr><tr><td>340164</td><td>2018-04-25</td></tr><tr><td>342721</td><td>2018-04-19</td></tr><tr><td>353541</td><td>2018-02-13</td></tr><tr><td>280132</td><td>2018-03-25</td></tr><tr><td>61064</td><td>2018-03-19</td></tr><tr><td>340300</td><td>2018-05-12</td></tr><tr><td>363533</td><td>2018-05-10</td></tr><tr><td>24701</td><td>2018-03-28</td></tr><tr><td>62327</td><td>2018-04-24</td></tr><tr><td>92135</td><td>2018-05-19</td></tr><tr><td>243549</td><td>2018-06-04</td></tr><tr><td>25082</td><td>2018-04-07</td></tr><tr><td>370959</td><td>2018-03-02</td></tr><tr><td>193418</td><td>2018-05-17</td></tr><tr><td>345678</td><td>2018-04-28</td></tr><tr><td>182629</td><td>2018-06-14</td></tr><tr><td>225306</td><td>2018-02-21</td></tr><tr><td>30247</td><td>2018-04-11</td></tr><tr><td>14424</td><td>2018-05-18</td></tr><tr><td>255644</td><td>2018-04-13</td></tr><tr><td>249216</td><td>2018-04-30</td></tr><tr><td>22616</td><td>2018-03-11</td></tr><tr><td>372527</td><td>2018-06-23</td></tr><tr><td>352865</td><td>2018-02-03</td></tr><tr><td>158534</td><td>2018-06-18</td></tr><tr><td>75374</td><td>2018-06-29</td></tr><tr><td>263784</td><td>2018-03-02</td></tr><tr><td>94826</td><td>2018-07-07</td></tr><tr><td>209341</td><td>2018-05-21</td></tr><tr><td>341457</td><td>2018-04-22</td></tr><tr><td>30343</td><td>2 ...

# %% [markdown]
# ### Extract the label
#
# hint:
# * use the posts history dataset and see what influencers posted on 1.8.2018 and assign them label 1
#  * use withColumn() transormation together with lit(1) which adds a column with constant value 1
#  * see lit() function in <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.functions.lit">docs</a> with example
# * left join this on the influencers and those records with null value will have label 0

# %%
label = (
  posts_history
  .filter(col('post_date') == '2018-08-01')
  .select('influencer_id')
  .distinct()
  .withColumn('label', lit(1))
)

influencers_with_label = (
  infl
  .join(label, 'influencer_id', 'left')
  .withColumn('label', coalesce('label', lit(0)))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### You may also want to check how many datapoints you have for each class
#
# hint
# * use groupBy('label').count()

# %%
display(
  influencers_with_label
  .groupBy('label')
  .agg(count('*').alias('ct'))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>ct</th></tr></thead><tbody><tr><td>1</td><td>123810</td></tr><tr><td>0</td><td>265743</td></tr></tbody></table></div>

# %%
display(influencers_with_label)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th><th>label</th></tr></thead><tbody><tr><td>148</td><td>List(pt)</td><td>List(Fitness and wellness)</td><td>0</td></tr><tr><td>463</td><td>List(de)</td><td>List(Food and drink, Business and industry, Sports and outdoors)</td><td>0</td></tr><tr><td>471</td><td>List(ru)</td><td>List(Fitness and wellness)</td><td>0</td></tr><tr><td>496</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Entertainment)</td><td>0</td></tr><tr><td>833</td><td>List(es)</td><td>List(Fitness and wellness)</td><td>0</td></tr><tr><td>1088</td><td>List(ru)</td><td>List(Business and industry, Hobbies and activities, Shopping and fashion)</td><td>1</td></tr><tr><td>1238</td><td>List(es)</td><td>List(Family and relationships, Fitness and wellness)</td><td>1</td></tr><tr><td>1342</td><td>List(en)</td><td>List(Hobbies and activities, Fitness and wellness, Business and industry)</td><td>1</td></tr><tr><td>1580</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>1591</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td></tr><tr><td>1645</td><td>List(pl)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>1829</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>1959</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>2122</td><td>List(en)</td><td>List(Fitness and wellness, Hobbies and activities)</td><td>0</td></tr><tr><td>2142</td><td>List(pt)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>2366</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td></tr><tr><td>2659</td><td>List(en, pl)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>2866</td><td>List(en)</td><td>List(Shopping and fashion, Hobbies and activities, Food and drink)</td><td>1</td></tr><tr><td>3175</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>3749</td><td>List(en)</td><td>List(Food and drink)</td><td>0</td></tr><tr><td>3794</td><td>List(ru)</td><td>List(Shopping and fashion)</td><td>0</td></tr><tr><td>3918</td><td>List(en)</td><td>List(Hobbies and activities, Shopping and fashion)</td><td>1</td></tr><tr><td>3997</td><td>List(en)</td><td>List(Entertainment, Fitness and wellness)</td><td>0</td></tr><tr><td>4101</td><td>List(en, es)</td><td>List(Hobbies and activities, Business and industry)</td><td>0</td></tr><tr><td>4519</td><td>List(en)</td><td>List(Food and drink, Hobbies and activities, Family and relationships)</td><td>1</td></tr><tr><td>4818</td><td>List(es)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>4900</td><td>List(ru)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>4935</td><td>List(pt)</td><td>List(Hobbies and activities, Family and relationships)</td><td>1</td></tr><tr><td>5156</td><td>List(ru)</td><td>List(Business and industry)</td><td>0</td></tr><tr><td>5300</td><td>List(pt)</td><td>List(Shopping and fashion)</td><td>0</td></tr><tr><td>5518</td><td>List(en)</td><td>List(Fitness and wellness)</td><td>0</td></tr><tr><td>5803</td><td>List(fa)</td><td>List(Entertainment, Hobbies and activities)</td><td>0</td></tr><tr><td>6336</td><td>List(en)</td><td>List(Sports and outdoors, Family and relationships)</td><td>0</td></tr><tr><td>6357</td><td>List(en)</td><td>List(Business and industry, Hobbies and activities, Technology)</td><td>0</td></tr><tr><td>6397</td><td>List(en)</td><td>List(Food and drink, Shopping and fashion, Business and industry)</td><td>1</td></tr><tr><td>6466</td><td>List(pt)</td><td>List(Hobbies and activities, Family and relationships)</td><td>0</td></tr><tr><td>6620</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td></tr><tr><td>6654</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td></tr><tr><td>6658</td><td>List(en)</td><td>L ...

# %% [markdown]
# ### Construct some basic features
#
# hint:
# * you may try number of interests, number of languages, age
# * interests and language cols are of ArrayType
#  * you can use <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.functions.size">size</a> function to count number of its elements
#  * the slide 48 in the prezentation might be useful for using functions on arrays

# %%
data_with_basic_features = (
  influencers_with_label
  .withColumn('num_interests', size('interests'))
  .withColumn('num_languages', size('languages'))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data_with_basic_features)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th><th>label</th><th>num_interests</th><th>num_languages</th></tr></thead><tbody><tr><td>148</td><td>List(pt)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>463</td><td>List(de)</td><td>List(Food and drink, Business and industry, Sports and outdoors)</td><td>0</td><td>3</td><td>1</td></tr><tr><td>471</td><td>List(ru)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>496</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Entertainment)</td><td>0</td><td>3</td><td>1</td></tr><tr><td>833</td><td>List(es)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1088</td><td>List(ru)</td><td>List(Business and industry, Hobbies and activities, Shopping and fashion)</td><td>1</td><td>3</td><td>1</td></tr><tr><td>1238</td><td>List(es)</td><td>List(Family and relationships, Fitness and wellness)</td><td>1</td><td>2</td><td>1</td></tr><tr><td>1342</td><td>List(en)</td><td>List(Hobbies and activities, Fitness and wellness, Business and industry)</td><td>1</td><td>3</td><td>1</td></tr><tr><td>1580</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1591</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1645</td><td>List(pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1829</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>1959</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>2122</td><td>List(en)</td><td>List(Fitness and wellness, Hobbies and activities)</td><td>0</td><td>2</td><td>1</td></tr><tr><td>2142</td><td>List(pt)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>2366</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>2659</td><td>List(en, pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>2</td></tr><tr><td>2866</td><td>List(en)</td><td>List(Shopping and fashion, Hobbies and activities, Food and drink)</td><td>1</td><td>3</td><td>1</td></tr><tr><td>3175</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>3749</td><td>List(en)</td><td>List(Food and drink)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>3794</td><td>List(ru)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>3918</td><td>List(en)</td><td>List(Hobbies and activities, Shopping and fashion)</td><td>1</td><td>2</td><td>1</td></tr><tr><td>3997</td><td>List(en)</td><td>List(Entertainment, Fitness and wellness)</td><td>0</td><td>2</td><td>1</td></tr><tr><td>4101</td><td>List(en, es)</td><td>List(Hobbies and activities, Business and industry)</td><td>0</td><td>2</td><td>2</td></tr><tr><td>4519</td><td>List(en)</td><td>List(Food and drink, Hobbies and activities, Family and relationships)</td><td>1</td><td>3</td><td>1</td></tr><tr><td>4818</td><td>List(es)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>4900</td><td>List(ru)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>4935</td><td>List(pt)</td><td>List(Hobbies and activities, Family and relationships)</td><td>1</td><td>2</td><td>1</td></tr><tr><td>5156</td><td>List(ru)</td><td>List(Business and industry)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>5300</td><td>List(pt)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>5518</td><td>List(en)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td></tr><tr><td>5803</td><td>List(fa)</td><td>List(Entertainment, Hobbies and activities)</td><td>0</td><td>2</td><td>1 ...

# %% [markdown]
# ### Split the data for training and testing
#
# hint
# * use the function <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame.randomSplit">randomSplit</a>
# * see the slide 99 in the presentation

# %%
(train, test) = data_with_basic_features.randomSplit([0.7, 0.3], 24)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Construct & fit the pipeline
#
# hint:
# * use <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.VectorAssembler">VectorAssembler</a> to create the input features
# * choose your model
#  * for LR use <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.classification.RandomForestClassifier">RandomForestClassifier</a>
#  * for RF use <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.classification.LogisticRegression">LogisticRegression</a>
#  * for DT use <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.classification.DecisionTreeClassifier">DecisionTreeClassifier</a>
# * the slide 104 in the prezentation might be useful for constructing the pipeline
# * use train data for training

# %%
# features:
features_array = ['num_interests', 'num_languages']

# Assambler:
assembler = VectorAssembler(inputCols=(features_array), outputCol='features')

# Classifier:
rf = RandomForestClassifier(labelCol='label', featuresCol='features', seed=42)

pipeline = Pipeline(stages=[assembler, rf])

rf_model = pipeline.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Evaluate the model
#
# hint:
# * use the <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.evaluation.BinaryClassificationEvaluator">BinaryClassificationEvaluator</a>
# * the slide 106 in the prezentation might be useful for evaluating binary classification
# * use the test data for evaluation

# %%
evaluator = BinaryClassificationEvaluator(labelCol='label', metricName='areaUnderROC')

predictions = rf_model.transform(test)

evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>0.5470120307361159
# </div>

# %%
display(predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th><th>label</th><th>num_interests</th><th>num_languages</th><th>features</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>148</td><td>List(pt)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>List(1, 2, List(), List(1.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>463</td><td>List(de)</td><td>List(Food and drink, Business and industry, Sports and outdoors)</td><td>0</td><td>3</td><td>1</td><td>List(1, 2, List(), List(3.0, 1.0))</td><td>List(1, 2, List(), List(13.392566048503358, 6.607433951496642))</td><td>List(1, 2, List(), List(0.6696283024251679, 0.3303716975748321))</td><td>0.0</td></tr><tr><td>496</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Entertainment)</td><td>0</td><td>3</td><td>1</td><td>List(1, 2, List(), List(3.0, 1.0))</td><td>List(1, 2, List(), List(13.392566048503358, 6.607433951496642))</td><td>List(1, 2, List(), List(0.6696283024251679, 0.3303716975748321))</td><td>0.0</td></tr><tr><td>1088</td><td>List(ru)</td><td>List(Business and industry, Hobbies and activities, Shopping and fashion)</td><td>1</td><td>3</td><td>1</td><td>List(1, 2, List(), List(3.0, 1.0))</td><td>List(1, 2, List(), List(13.392566048503358, 6.607433951496642))</td><td>List(1, 2, List(), List(0.6696283024251679, 0.3303716975748321))</td><td>0.0</td></tr><tr><td>1238</td><td>List(es)</td><td>List(Family and relationships, Fitness and wellness)</td><td>1</td><td>2</td><td>1</td><td>List(1, 2, List(), List(2.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>1829</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>List(1, 2, List(), List(1.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>2122</td><td>List(en)</td><td>List(Fitness and wellness, Hobbies and activities)</td><td>0</td><td>2</td><td>1</td><td>List(1, 2, List(), List(2.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>2142</td><td>List(pt)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>List(1, 2, List(), List(1.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>2659</td><td>List(en, pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>2</td><td>List(1, 2, List(), List(1.0, 2.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>3749</td><td>List(en)</td><td>List(Food and drink)</td><td>0</td><td>1</td><td>1</td><td>List(1, 2, List(), List(1.0, 1.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>4101</td><td>List(en, es)</td><td>List(Hobbies and activities, Business and industry)</td><td>0</td><td>2</td><td>2</td><td>List(1, 2, List(), List(2.0, 2.0))</td><td>List(1, 2, List(), List(13.714821754258566, 6.2851782457414345))</td><td>List(1, 2, List(), List(0.6857410877129283, 0.3142589122870717))</td><td>0.0</td></tr><tr><td>4935</td><td>List(pt)</td><td>List(Hobbies and activities, Family and relationships)</td><td>1</td><td>2</ ...

# %% [markdown]
# The accuracy is not very great. Perhaps we can improve it by some more predictors

# %% [markdown]
# ### Try to improve the model
#
# hint:
# * you may try also some categorical features like the value of the interest
# * the slide 88, 94 in the prezentation might be useful for OneHotEncoder and StringIndexer

# %%
data_with_catagorical_feature = (
  data_with_basic_features.withColumn('interest', col('interests')[0])
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data_with_catagorical_feature)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th><th>label</th><th>num_interests</th><th>num_languages</th><th>interest</th></tr></thead><tbody><tr><td>148</td><td>List(pt)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td></tr><tr><td>463</td><td>List(de)</td><td>List(Food and drink, Business and industry, Sports and outdoors)</td><td>0</td><td>3</td><td>1</td><td>Food and drink</td></tr><tr><td>471</td><td>List(ru)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td></tr><tr><td>496</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Entertainment)</td><td>0</td><td>3</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>833</td><td>List(es)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td></tr><tr><td>1088</td><td>List(ru)</td><td>List(Business and industry, Hobbies and activities, Shopping and fashion)</td><td>1</td><td>3</td><td>1</td><td>Business and industry</td></tr><tr><td>1238</td><td>List(es)</td><td>List(Family and relationships, Fitness and wellness)</td><td>1</td><td>2</td><td>1</td><td>Family and relationships</td></tr><tr><td>1342</td><td>List(en)</td><td>List(Hobbies and activities, Fitness and wellness, Business and industry)</td><td>1</td><td>3</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>1580</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>1591</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td></tr><tr><td>1645</td><td>List(pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>1829</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>1959</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>2122</td><td>List(en)</td><td>List(Fitness and wellness, Hobbies and activities)</td><td>0</td><td>2</td><td>1</td><td>Fitness and wellness</td></tr><tr><td>2142</td><td>List(pt)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>2366</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td></tr><tr><td>2659</td><td>List(en, pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>2</td><td>Hobbies and activities</td></tr><tr><td>2866</td><td>List(en)</td><td>List(Shopping and fashion, Hobbies and activities, Food and drink)</td><td>1</td><td>3</td><td>1</td><td>Shopping and fashion</td></tr><tr><td>3175</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>3749</td><td>List(en)</td><td>List(Food and drink)</td><td>0</td><td>1</td><td>1</td><td>Food and drink</td></tr><tr><td>3794</td><td>List(ru)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td></tr><tr><td>3918</td><td>List(en)</td><td>List(Hobbies and activities, Shopping and fashion)</td><td>1</td><td>2</td><td>1</td><td>Hobbies and activities</td></tr><tr><td>3997</td><td>List(en)</td><td>List(Entertainment, Fitness and wellness)</td><td>0</td><td>2</td><td>1</td><td>Entertainment</td></tr><tr><td>4101</td><td>List(en, es)</td><td>List(Hobbies and activities, Business and industry)</td><td>0</td><td>2</td><td>2</td><td>Hobbies and activities</td></tr><tr><td>4519</td><td>List(en)</td><td>List(Food and drink, Hobbies and activities, Family and relationships)</td><td>1</td><td>3</td><td>1</td><td>Food and drink</td></tr><tr><td>4818</td><td>Lis ...

# %%
(train, test) = data_with_catagorical_feature.randomSplit([0.7, 0.3], 24)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# features:

features_array = ['num_interests', 'num_languages']

# indexer
interestIndexer = StringIndexer(inputCol='interest', outputCol='indexedInterest')

# OneHotEncoders:
interestEncoder = OneHotEncoder(inputCol='indexedInterest', outputCol='interestVec')

# Assambler:
assembler = VectorAssembler(inputCols=(features_array + ['interestVec']), outputCol='features')

# Classifier:
rf = RandomForestClassifier(featuresCol='features', seed=42)

pipeline = Pipeline(stages=[interestIndexer, interestEncoder, assembler, rf])

rf_model = pipeline.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluator = BinaryClassificationEvaluator(labelCol='label', metricName='areaUnderROC')

predictions = rf_model.transform(test)

evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>0.5645606161697516
# </div>

# %% [markdown]
# The accuracy is slightly better but still not very good. Let's see if we can improve it even better:

# %% [markdown]
# ### Improve the model even more
#
# hint:
# * construct some features that capture how frequently the influencer posts
# * extract these features from the posting history

# %%
history_for_features = (
  posts_history
  .filter(col('post_date') <= '2018-07-31')
)

time_from_last_post = (
  history_for_features
  .groupBy('influencer_id')
  .agg(
    max('post_date').alias('last_post')
  )
  .withColumn('time_from_last_post', datediff(lit('2018-07-31'), col('last_post')))
  .select('influencer_id', 'time_from_last_post')
)

number_of_posts = (
  history_for_features
  .groupBy('influencer_id')
  .agg(
    count('*').alias('number_of_posts')
  )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_features_improved = (
  data_with_catagorical_feature
  .join(time_from_last_post, 'influencer_id')
  .join(number_of_posts, 'influencer_id')
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(data_features_improved)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>influencer_id</th><th>languages</th><th>interests</th><th>label</th><th>num_interests</th><th>num_languages</th><th>interest</th><th>time_from_last_post</th><th>number_of_posts</th></tr></thead><tbody><tr><td>148</td><td>List(pt)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td><td>17</td><td>13</td></tr><tr><td>463</td><td>List(de)</td><td>List(Food and drink, Business and industry, Sports and outdoors)</td><td>0</td><td>3</td><td>1</td><td>Food and drink</td><td>1</td><td>91</td></tr><tr><td>471</td><td>List(ru)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td><td>1</td><td>27</td></tr><tr><td>496</td><td>List(en)</td><td>List(Hobbies and activities, Business and industry, Entertainment)</td><td>0</td><td>3</td><td>1</td><td>Hobbies and activities</td><td>0</td><td>123</td></tr><tr><td>833</td><td>List(es)</td><td>List(Fitness and wellness)</td><td>0</td><td>1</td><td>1</td><td>Fitness and wellness</td><td>0</td><td>92</td></tr><tr><td>1088</td><td>List(ru)</td><td>List(Business and industry, Hobbies and activities, Shopping and fashion)</td><td>1</td><td>3</td><td>1</td><td>Business and industry</td><td>1</td><td>224</td></tr><tr><td>1238</td><td>List(es)</td><td>List(Family and relationships, Fitness and wellness)</td><td>1</td><td>2</td><td>1</td><td>Family and relationships</td><td>0</td><td>142</td></tr><tr><td>1342</td><td>List(en)</td><td>List(Hobbies and activities, Fitness and wellness, Business and industry)</td><td>1</td><td>3</td><td>1</td><td>Hobbies and activities</td><td>0</td><td>205</td></tr><tr><td>1580</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>21</td><td>13</td></tr><tr><td>1591</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td><td>22</td><td>52</td></tr><tr><td>1645</td><td>List(pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>0</td><td>45</td></tr><tr><td>1829</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>1</td><td>109</td></tr><tr><td>1959</td><td>List(en)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>4</td><td>62</td></tr><tr><td>2122</td><td>List(en)</td><td>List(Fitness and wellness, Hobbies and activities)</td><td>0</td><td>2</td><td>1</td><td>Fitness and wellness</td><td>1</td><td>140</td></tr><tr><td>2142</td><td>List(pt)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>6</td><td>29</td></tr><tr><td>2366</td><td>List(en)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td><td>0</td><td>81</td></tr><tr><td>2659</td><td>List(en, pl)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>2</td><td>Hobbies and activities</td><td>0</td><td>71</td></tr><tr><td>2866</td><td>List(en)</td><td>List(Shopping and fashion, Hobbies and activities, Food and drink)</td><td>1</td><td>3</td><td>1</td><td>Shopping and fashion</td><td>2</td><td>165</td></tr><tr><td>3175</td><td>List(zh)</td><td>List(Hobbies and activities)</td><td>0</td><td>1</td><td>1</td><td>Hobbies and activities</td><td>41</td><td>69</td></tr><tr><td>3749</td><td>List(en)</td><td>List(Food and drink)</td><td>0</td><td>1</td><td>1</td><td>Food and drink</td><td>1</td><td>93</td></tr><tr><td>3794</td><td>List(ru)</td><td>List(Shopping and fashion)</td><td>0</td><td>1</td><td>1</td><td>Shopping and fashion</td><td>2</td><td>75</td></tr><tr><td>3918</td><td>List(en)</td><td>List(Hobbies and activities, Shopping and fashion)</td><td>1</td><td>2</td><td>1</td><td>Hobbies and activities</td>< ...

# %%
(train, test) = data_features_improved.randomSplit([0.7, 0.3], 24)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# features:
features_array = ['num_interests', 'num_languages', 'time_from_last_post', 'number_of_posts']

# indexer
interestIndexer = StringIndexer(inputCol='interest', outputCol='indexedInterest')

# OneHotEncoders:
interestEncoder = OneHotEncoder(inputCol='indexedInterest', outputCol='interestVec')

# Assambler:
assembler = VectorAssembler(inputCols=(features_array), outputCol='features')

# Classifier:
rf = RandomForestClassifier(featuresCol='features', seed=42)

pipeline = Pipeline(stages=[interestIndexer, interestEncoder, assembler, rf])

rf_model = pipeline.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluator = BinaryClassificationEvaluator(labelCol="label", metricName="areaUnderROC")

predictions = rf_model.transform(test)

evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">28</span><span class="ansired">]: </span>0.7032369733549294
# </div>

# %% [markdown]
# ### Try crossvalidation
#
# hint
# * the slide 108 in the prezentation might be useful for tunning hyperparameters
# * check in the documentation what parameters has your model (maxDepth, numTrees for Random Forrest)

# %%
paramGrid = (
  ParamGridBuilder()
  .addGrid(rf.maxDepth, [3, 5, 8])
  .addGrid(rf.numTrees, [50, 100, 150])
  .build()
)

cross_model = CrossValidator(estimator=pipeline, evaluator=evaluator, estimatorParamMaps=paramGrid).fit(train)

rf_model = cross_model.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = rf_model.transform(test)
evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">30</span><span class="ansired">]: </span>0.7160918402617341
# </div>

# %% [markdown]
# ## See some properties of the final model
#
# Note
# * This depends on the model you are using
#
# Hint
# * For Random Forest see the API of the model in <a target="_blank" href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.classification.RandomForestClassificationModel">docs</a>
# * Example to see number of trees:
#  * rf_model.stages[n].getNumTrees and here rf_model is your trained model and n is index of RF in your pipeline

# %%
rf_model.stages[3].getNumTrees
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">31</span><span class="ansired">]: </span>100
# </div>

# %%
rf_model.stages[3].totalNumNodes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>11080
# </div>

# %%
rf_model.stages[3].trees
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">33</span><span class="ansired">]: </span>
# [DecisionTreeClassificationModel (uid=dtc_f110def9f194) of depth 8 with 113 nodes,
#  DecisionTreeClassificationModel (uid=dtc_126c0f3bdafe) of depth 8 with 95 nodes,
#  DecisionTreeClassificationModel (uid=dtc_59be50322cc2) of depth 8 with 99 nodes,
#  DecisionTreeClassificationModel (uid=dtc_9f1ef754120c) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_4ea29359258c) of depth 8 with 137 nodes,
#  DecisionTreeClassificationModel (uid=dtc_2ee9c8ee42f6) of depth 8 with 103 nodes,
#  DecisionTreeClassificationModel (uid=dtc_92617eb417f5) of depth 8 with 139 nodes,
#  DecisionTreeClassificationModel (uid=dtc_39e403a9fb07) of depth 8 with 107 nodes,
#  DecisionTreeClassificationModel (uid=dtc_0f0c9ced01ae) of depth 8 with 125 nodes,
#  DecisionTreeClassificationModel (uid=dtc_8a7997871eb8) of depth 8 with 83 nodes,
#  DecisionTreeClassificationModel (uid=dtc_7926e069a84a) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_f1a3f4fa0284) of depth 8 with 97 nodes,
#  DecisionTreeClassificationModel (uid=dtc_64cbf1a07b6b) of depth 8 with 127 nodes,
#  DecisionTreeClassificationModel (uid=dtc_d68c62dbdc21) of depth 8 with 135 nodes,
#  DecisionTreeClassificationModel (uid=dtc_c9946061f5d5) of depth 8 with 103 nodes,
#  DecisionTreeClassificationModel (uid=dtc_c3983f7c32fe) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_abc06843b5aa) of depth 8 with 125 nodes,
#  DecisionTreeClassificationModel (uid=dtc_52c376cb8975) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_fdc8170959f8) of depth 8 with 125 nodes,
#  DecisionTreeClassificationModel (uid=dtc_916636c315bc) of depth 8 with 123 nodes,
#  DecisionTreeClassificationModel (uid=dtc_852b008c2395) of depth 8 with 99 nodes,
#  DecisionTreeClassificationModel (uid=dtc_7f91dd00ff9d) of depth 8 with 107 nodes,
#  DecisionTreeClassificationModel (uid=dtc_27778594d90d) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_1eeb2e0f45f8) of depth 8 with 159 nodes,
#  DecisionTreeClassificationModel (uid=dtc_a9f2b9a6eab2) of depth 8 with 129 nodes,
#  DecisionTreeClassificationModel (uid=dtc_e1dfe8433965) of depth 8 with 127 nodes,
#  DecisionTreeClassificationModel (uid=dtc_055e5bb4711d) of depth 8 with 129 nodes,
#  DecisionTreeClassificationModel (uid=dtc_59e40eea1b22) of depth 8 with 81 nodes,
#  DecisionTreeClassificationModel (uid=dtc_58ef14b7fec7) of depth 8 with 71 nodes,
#  DecisionTreeClassificationModel (uid=dtc_65b41d434508) of depth 8 with 105 nodes,
#  DecisionTreeClassificationModel (uid=dtc_826ed36d6531) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_6b81b19689aa) of depth 8 with 141 nodes,
#  DecisionTreeClassificationModel (uid=dtc_29f8dd7b4620) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_85f833b68d35) of depth 8 with 161 nodes,
#  DecisionTreeClassificationModel (uid=dtc_5f0c05fa74a5) of depth 8 with 139 nodes,
#  DecisionTreeClassificationModel (uid=dtc_ce3ec47e9e6b) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_4f2ababc7fa6) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_4c1a6fc2588a) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_e83fa39415e5) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_7b91ef4cf2ed) of depth 8 with 81 nodes,
#  DecisionTreeClassificationModel (uid=dtc_2db0943bc20e) of depth 8 with 113 nodes,
#  DecisionTreeClassificationModel (uid=dtc_21c4ea47afb8) of depth 8 with 123 nodes,
#  DecisionTreeClassificationModel (uid=dtc_f4598f295ea3) of depth 8 with 161 nodes,
#  DecisionTreeClassificationModel (uid=dtc_0223e425a3ea) of depth 8 with 97 nodes,
#  DecisionTreeClassificationModel (uid=dtc_dcc88009254d) of depth 8 with 105 nodes,
#  DecisionTreeClassificationModel (uid=dtc_9c154d72799f) of depth 8 with 103 nodes,
#  DecisionTreeClassificationModel (uid=dtc_10034788184a) of depth 8 with 77 nodes,
#  DecisionTreeClassificationModel (uid=dtc_0c4a02463abe) of depth 8 with 91 nodes,
#  DecisionTreeClassificationModel (uid=dtc_22af5ee05ab9) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_ed9f530e9861) of depth 8 with 121 nodes,
#  DecisionTreeClassificationModel (uid=dtc_9b3b0656614b) of depth 8 with 111 nodes,
#  DecisionTreeClassificationModel (uid=dtc_e5ff3d9e5892) of depth 8 with 99 nodes,
#  DecisionTreeClassificationModel (uid=dtc_177a8381f711) of depth 8 with 85 nodes,
#  DecisionTreeClassificationModel (uid=dtc_02eb76402162) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_fa38d647f51a) of depth 8 with 79 nodes,
#  DecisionTreeClassificationModel (uid=dtc_00b748c0d94f) of depth 8 with 85 nodes,
#  DecisionTreeClassificationModel (uid=dtc_4f2336f615fd) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_3bf2462f5866) of depth 8 with 97 nodes,
#  DecisionTreeClassificationModel (uid=dtc_bcec8dc3b876) of depth 8 with 105 nodes,
#  DecisionTreeClassificationModel (uid=dtc_546297fd1ac2) of depth 8 with 91 nodes,
#  DecisionTreeClassificationModel (uid=dtc_58200cd6c6fe) of depth 8 with 85 nodes,
#  DecisionTreeClassificationModel (uid=dtc_03f988d47ba2) of depth 8 with 137 nodes,
#  DecisionTreeClassificationModel (uid=dtc_a5fd14ace628) of depth 8 with 79 nodes,
#  DecisionTreeClassificationModel (uid=dtc_5273b02a2cfb) of depth 8 with 99 nodes,
#  DecisionTreeClassificationModel (uid=dtc_2cbd0023a2b1) of depth 8 with 141 nodes,
#  DecisionTreeClassificationModel (uid=dtc_953f536f1fc0) of depth 8 with 101 nodes,
#  DecisionTreeClassificationModel (uid=dtc_803bbdf2164d) of depth 8 with 95 nodes,
#  DecisionTreeClassificationModel (uid=dtc_058333dd4e35) of depth 8 with 105 nodes,
#  DecisionTreeClassificationModel (uid=dtc_34675084904e) of depth 8 with 123 nodes,
#  DecisionTreeClassificationModel (uid=dtc_c5efc227d2c0) of depth 8 with 131 nodes,
#  DecisionTreeClassificationModel (uid=dtc_b92ae6f54bb7) of depth 8 with 127 nodes,
#  DecisionTreeClassificationModel (uid=dtc_7fac42a18101) of depth 8 with 103 nodes,
#  DecisionTreeClassificationModel (uid=dtc_149a72d1a4ec) of depth 8 with 127 nodes,
#  DecisionTreeClassificationModel (uid=dtc_b4d51896dbc9) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_5381ad96baaf) of depth 8 with 95 nodes,
#  DecisionTreeClassificationModel (uid=dtc_941edc1f14c7) of depth 8 with 107 nodes,
#  DecisionTreeClassificationModel (uid=dtc_dec058df30c1) of depth 8 with 135 nodes,
#  DecisionTreeClassificationModel (uid=dtc_9a7234cb2bc4) of depth 8 with 103 nodes,
#  DecisionTreeClassificationModel (uid=dtc_f222f43d667b) of depth 8 with 107 nodes,
#  DecisionTreeClassificationModel (uid=dtc_7c5ae3fd6159) of depth 8 with 107 nodes,
#  DecisionTreeClassificationModel (uid=dtc_e03be4177cce) of depth 8 with 141 nodes,
#  DecisionTreeClassificationModel (uid=dtc_1f6052c40414) of depth 8 with 127 nodes,
#  DecisionTreeClassificationModel (uid=dtc_47cef3d3e635) of depth 8 with 87 nodes,
#  DecisionTreeClassificationModel (uid=dtc_1bda966f4bcd) of depth 8 with 83 nodes,
#  DecisionTreeClassificationModel (uid=dtc_96819e336859) of depth 8 with 119 nodes,
#  DecisionTreeClassificationModel (uid=dtc_9ac6e362015f) of depth 8 with 135 nodes,
#  DecisionTreeClassificationModel (uid=dtc_83714f75ea36) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_436f51c0b870) of depth 8 with 83 nodes,
#  DecisionTreeClassificationModel (uid=dtc_b8f404288a68) of depth 8 with 73 nodes,
#  DecisionTreeClassificationModel (uid=dtc_3b17eee76222) of depth 8 with 117 nodes,
#  DecisionTreeClassificationModel (uid=dtc_3f250a366c06) of depth 8 with 109 nodes,
#  DecisionTreeClassificationModel (uid=dtc_788857

# %%
rf_model.stages[3].toDebugString
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">34</span><span class="ansired">]: </span>&apos;RandomForestClassificationModel (uid=RandomForestClassifier_7a0002b6d4ef) with 100 trees\n  Tree 0 (weight 1.0):\n    If (feature 3 &lt;= 111.5)\n     If (feature 3 &lt;= 55.5)\n      If (feature 2 &lt;= 3.5)\n       If (feature 1 &lt;= 1.5)\n        If (feature 0 &lt;= 2.5)\n         Predict: 0.0\n        Else (feature 0 &gt; 2.5)\n         If (feature 3 &lt;= 31.5)\n          If (feature 2 &lt;= 0.5)\n           If (feature 3 &lt;= 18.5)\n            Predict: 1.0\n           Else (feature 3 &gt; 18.5)\n            Predict: 0.0\n          Else (feature 2 &gt; 0.5)\n           If (feature 1 &lt;= 0.0)\n            Predict: 1.0\n           Else (feature 1 &gt; 0.0)\n            Predict: 0.0\n         Else (feature 3 &gt; 31.5)\n          Predict: 0.0\n       Else (feature 1 &gt; 1.5)\n        If (feature 1 &lt;= 2.5)\n         Predict: 0.0\n        Else (feature 1 &gt; 2.5)\n         If (feature 3 &lt;= 50.5)\n          If (feature 0 &lt;= 1.5)\n           Predict: 0.0\n          Else (feature 0 &gt; 1.5)\n           If (feature 2 &lt;= 1.5)\n            Predict: 1.0\n           Else (feature 2 &gt; 1.5)\n            Predict: 0.0\n         Else (feature 3 &gt; 50.5)\n          Predict: 1.0\n      Else (feature 2 &gt; 3.5)\n       If (feature 2 &lt;= 15.5)\n        If (feature 3 &lt;= 31.5)\n         Predict: 0.0\n        Else (feature 3 &gt; 31.5)\n         If (feature 2 &lt;= 7.5)\n          Predict: 0.0\n         Else (feature 2 &gt; 7.5)\n          If (feature 2 &lt;= 8.5)\n           If (feature 1 &lt;= 0.0)\n            Predict: 1.0\n           Else (feature 1 &gt; 0.0)\n            Predict: 0.0\n          Else (feature 2 &gt; 8.5)\n           Predict: 0.0\n       Else (feature 2 &gt; 15.5)\n        Predict: 0.0\n     Else (feature 3 &gt; 55.5)\n      Predict: 0.0\n    Else (feature 3 &gt; 111.5)\n     If (feature 3 &lt;= 151.5)\n      If (feature 1 &lt;= 1.5)\n       If (feature 2 &lt;= 2.5)\n        If (feature 3 &lt;= 126.5)\n         If (feature 3 &lt;= 118.5)\n          Predict: 0.0\n         Else (feature 3 &gt; 118.5)\n          If (feature 2 &lt;= 0.5)\n           If (feature 0 &lt;= 1.5)\n            Predict: 1.0\n           Else (feature 0 &gt; 1.5)\n            Predict: 0.0\n          Else (feature 2 &gt; 0.5)\n           Predict: 0.0\n        Else (feature 3 &gt; 126.5)\n         Predict: 1.0\n       Else (feature 2 &gt; 2.5)\n        Predict: 0.0\n      Else (feature 1 &gt; 1.5)\n       If (feature 2 &lt;= 4.5)\n        If (feature 2 &lt;= 0.5)\n         If (feature 0 &lt;= 2.5)\n          If (feature 0 &lt;= 1.5)\n           If (feature 3 &lt;= 126.5)\n            Predict: 0.0\n           Else (feature 3 &gt; 126.5)\n            Predict: 1.0\n          Else (feature 0 &gt; 1.5)\n           Predict: 1.0\n         Else (feature 0 &gt; 2.5)\n          Predict: 0.0\n        Else (feature 2 &gt; 0.5)\n         If (feature 3 &lt;= 118.5)\n          Predict: 0.0\n         Else (feature 3 &gt; 118.5)\n          If (feature 0 &lt;= 1.5)\n           If (feature 3 &lt;= 137.5)\n            Predict: 0.0\n           Else (feature 3 &gt; 137.5)\n            Predict: 1.0\n          Else (feature 0 &gt; 1.5)\n           Predict: 0.0\n       Else (feature 2 &gt; 4.5)\n        If (feature 0 &lt;= 2.5)\n         If (feature 2 &lt;= 14.5)\n          If (feature 2 &lt;= 13.5)\n           Predict: 0.0\n          Else (feature 2 &gt; 13.5)\n           If (feature 3 &lt;= 118.5)\n            Predict: 1.0\n           Else (feature 3 &gt; 118.5)\n            Predict: 0.0\n         Else (feature 2 &gt; 14.5)\n          Predict: 0.0\n        Else (feature 0 &gt; 2.5)\n         If (feature 3 &lt;= 118.5)\n          Predict: 0.0\n         Else (feature 3 &gt; 118.5)\n          If (feature 2 &lt;= 5.5)\n           Predict: 1.0\n          Else (feature 2 &gt; 5.5)\n           Predict: 0.0\n     Else (feature 3 &gt; 151. ...
